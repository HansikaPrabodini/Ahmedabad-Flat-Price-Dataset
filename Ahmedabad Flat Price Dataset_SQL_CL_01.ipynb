# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from IPython.display import display, HTML

# %%
df = pd.read_csv('cl_04.csv')
df.head()
# Out:
#    F1                                              Title  area_value  \
# 0   6  2 BHK Apartment for Sale in Kavisha AER, Shela...       700.0
# 1   7  2 BHK Apartment for Sale in Vivaan Aura, Zunda...       765.0
# 2  11       2 BHK Apartment for Sale in Zundal Ahmedabad       774.0
# 3  15  2 BHK Apartment for Sale in Vivaan Essence, Zu...       774.0
# 4  16  2 BHK Apartment for Sale in Aadhvan Rise, Sout...       687.0
#
#    price_per_sqft  apartment_price     Property_status transaction_test  \
# 0          3900.0          4910000  Under Construction     New Property
# 1          3444.0          4840000  Under Construction     New Property
# 2          3968.0          4500000       Ready to Move           Resale
# 3          3556.0          4990000  Under Construction     New Property
# 4          4367.0          5000000       Ready to Move     New Property
#
#        Furnishing facing_direction    Area_type type_of_property  Bedrooms  \
# ...

# %% [markdown]
# #### Check NULL values

# %%
df.isnull().sum()
# Out:
# F1                         0
# Title                      0
# area_value                 1
# price_per_sqft           279
# apartment_price            0
# Property_status            0
# transaction_test           0
# Furnishing                16
# facing_direction        1807
# Area_type                  0
# type_of_property           0
# Bedrooms                   0
# location_area              0
# Property_Description    1440
# location_address           0
# apartment_floor            0
# building_floors            0
# dtype: int64

# %% [markdown]
# facing_direction and Property_Description somehow have a reliaonship
# becuase i get facing_direction clearly on searching Property_Description

# %%
df[df['Furnishing'].isnull()]
# Out:
#         F1                                              Title  area_value  \
# 167    338  3 BHK Apartment for Sale in Saujanya, Khokhra ...      1056.0
# 182    367  2 BHK Apartment for Sale in Shri Hari Sahitya ...       650.0
# 321   1290      1 BHK Apartment for Sale in Vastral Ahmedabad       495.0
# 357   1340     2 BHK Builder Floor for Sale in Gota Ahmedabad       184.0
# 752    954     1 BHK Apartment for Sale in Kankaria Ahmedabad        45.0
# 853   1120       Studio Apartment for Sale in Vatva Ahmedabad       258.0
# 1066  2264  3 BHK Apartment for Sale in Laxmikrupa Apartme...      1000.0
# 1427  2540     2 BHK Apartment for Sale in Jagatpur Ahmedabad      1550.0
# 1450  2577  2 BHK Apartment for Sale in Pacifica Reflectio...      1425.0
# 1620  2902  3 BHK Apartment for Sale in Prahalad nagher sa...      1800.0
# 1831  2102  2 BHK Apartment for Sale in Kaveri Trisara, Sh...      1285.0
# 2273  2728       3 BHK Apartment for Sale in Sanand Ahmedabad       900.0
# ...

# %% [markdown]
# #### find how many percentage of rows in NULL in price_per_sqft

# %%
df['price_per_sqft_Null'] = np.where(df['price_per_sqft'].isnull(), 1, 0)

## find the percentage of null values
percentage_null = df['price_per_sqft_Null'].mean() * 100


print(percentage_null)
# Out:
# 4.703304113283884

# %%
print(df.dtypes)

# %%
df.groupby(['Property_status'])['price_per_sqft_Null'].mean()
# Out:
# Property_status
# Call for Details      0.045455
# Ready to Move         0.060493
# Under Construction    0.017847
# Name: price_per_sqft_Null, dtype: float64

# %%
df.groupby(['transaction_test'])['price_per_sqft_Null'].mean()
# Out:
# transaction_test
# New Property    0.014313
# Other           0.888889
# Rent/Lease      0.000000
# Resale          0.061043
# Name: price_per_sqft_Null, dtype: float64

# %%
df.groupby(['Furnishing'])['price_per_sqft_Null'].mean()
# Out:
# Furnishing
# Furnished         0.052849
# Semi-Furnished    0.087359
# Unfurnished       0.034566
# Name: price_per_sqft_Null, dtype: float64

# %%
df.groupby(['Area_type'])['price_per_sqft_Null'].mean()
# Out:
# Area_type
# Built Area     0.000000
# Carpet Area    0.076838
# Super Area     0.000432
# Name: price_per_sqft_Null, dtype: float64

# %%
df.groupby(['type_of_property'])['price_per_sqft_Null'].mean()
# Out:
# type_of_property
# Apartment        0.048686
# Builder Floor    0.021739
# Penthouse        0.033195
# Studio           0.055556
# Name: price_per_sqft_Null, dtype: float64

# %%
df.groupby(['Bedrooms'])['price_per_sqft_Null'].mean()
# Out:
# Bedrooms
# 0    0.000000
# 1    0.131579
# 2    0.072702
# 3    0.048872
# 4    0.016572
# 5    0.016032
# 6    0.000000
# 7    0.000000
# 8    0.000000
# 9    0.000000
# Name: price_per_sqft_Null, dtype: float64

# %%
df.groupby(['apartment_floor'])['price_per_sqft_Null'].mean()
# Out:
# apartment_floor
# -1     0.049180
#  0     0.075188
#  1     0.070934
#  2     0.094231
#  3     0.067568
#  4     0.052550
#  5     0.040377
#  6     0.061047
#  7     0.024775
#  8     0.012539
#  9     0.025890
#  10    0.021201
#  11    0.016667
#  12    0.015228
#  13    0.020408
#  14    0.037975
#  15    0.011364
#  16    0.015873
#  17    0.000000
#  18    0.000000
#  19    0.000000
#  20    0.000000
#  21    0.045455
#  22    0.055556
#  23    0.222222
#  24    0.000000
#  25    0.100000
#  26    0.166667
#  27    0.250000
#  28    0.250000
#  29    0.250000
#  30    0.000000
#  31    0.000000
#  32    0.000000
#  33    0.000000
#  34    0.000000
#  35    0.000000
#  36    0.000000
# Name: price_per_sqft_Null, dtype: float64

# %%
df.groupby(['building_floors'])['price_per_sqft_Null'].mean()
# Out:
# building_floors
# 1     0.033333
# 2     0.200000
# 3     0.118919
# 4     0.108635
# 5     0.083682
# 6     0.029851
# 7     0.081667
# 8     0.051020
# 9     0.029412
# 10    0.045147
# 11    0.026144
# 12    0.031325
# 13    0.028302
# 14    0.018757
# 15    0.021739
# 16    0.000000
# 17    0.013514
# 18    0.000000
# 19    0.000000
# 20    0.008696
# 21    0.004975
# 22    0.006826
# 23    0.013514
# 24    0.000000
# 25    0.000000
# 26    0.000000
# 27    0.000000
# 28    0.000000
# 29    0.000000
# 30    0.000000
# 31    0.177419
# 32    0.021739
# 33    0.000000
# 34    0.000000
# 35    0.000000
# 36    0.000000
# 37    0.016667
# 38    0.000000
# 40    0.000000
# 41    0.000000
# 52    0.000000
# Name: price_per_sqft_Null, dtype: float64

# %% [markdown]
# #### Check Outliers - Using boxplots

# %%
column_name = 'area_value'  

plt.figure(figsize=(10, 30))
sns.boxplot(df[column_name])
plt.title(f'Box Plot of {column_name}')
plt.xlabel(column_name)
plt.show()

# %%
column_name = 'building_floors'  

plt.figure(figsize=(10, 30))
sns.boxplot(df[column_name])
plt.title(f'Box Plot of {column_name}')
plt.xlabel(column_name)
plt.show()

# %% [markdown]
# ##### Create a frequency chart (Bar Plot) of  building_floors - need to know counts

# %%
column_name = 'building_floors'


plt.figure(figsize=(10, 6))
sns.countplot(data=df, x=column_name, palette='viridis')
plt.title(f'Frequency Chart of {column_name}')
plt.xlabel(column_name)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### box plot and frequency chart (Bar Plot) for apartment_floor

# %%
column_name = 'apartment_floor'  

plt.figure(figsize=(10, 30))
sns.boxplot(df[column_name])
plt.title(f'Box Plot of {column_name}')
plt.xlabel(column_name)
plt.show()

# %%
column_name = 'apartment_floor'


plt.figure(figsize=(10, 6))
sns.countplot(data=df, x=column_name, palette='viridis')
plt.title(f'Frequency Chart of {column_name}')
plt.xlabel(column_name)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ###### there is outlier where F1=6291 . i remove this outlier from data set

# %%
# Remove row where 'F1' column equals 6291
df = df[df['F1'] != 6291]
df = df.reset_index(drop=True)

#print("\nDataFrame after removing row with 'F1' = 6291:")
#print(df)

# %% [markdown]
# ###### check any connection for Bedrooms and area_value becuase 1 row has 0 bedrooms it cannot happened need to fulfill it

# %%
# Scatter plot of Bedrooms vs. Area Value
plt.figure(figsize=(10, 6))
plt.scatter(df['Bedrooms'], df['area_value'], alpha=0.5)
plt.title('Scatter Plot of Bedrooms vs. Area Value')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Area Value (sq ft)')
plt.grid(True)
plt.show()

## actaually i connot get any relationship between this

# %%
gota_df = df[df['location_area'] == 'Gota']
bedroom_counts = gota_df['Bedrooms'].value_counts().sort_index()

print("Count of Bedrooms in 'Gota' apartments:")
print(bedroom_counts)
# Out:
# Count of Bedrooms in 'Gota' apartments:
# 0      1
# 1     13
# 2     66
# 3    103
# 4     40
# 5      4
# Name: Bedrooms, dtype: int64

# %% [markdown]
# ##### this python file connected with SQL
# so in this case,
#
# update cl_05
# set Bedrooms =2
# where location_area = 'Gota'
# and apartment_floor =1
# and type_of_property='Apartment'
# and Area_type ='Super Area'
# and transaction_test ='Resale'
# and location_address ='Gota Ahmedabad'
# and Bedrooms =0
# using this update bedrooms

# %% [markdown]
# ##### Update 'Bedrooms' where value is 0 to 2

# %%
df.loc[df['Bedrooms'] == 0, 'Bedrooms'] = 2

#print("Updated DataFrame:")
#print(df)

# %%
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <title>
#    Property Rates in Ahmedabad - 2020 - Real Estate Property Price &amp; Trends in Ahmedabad
#   </title>
#   <meta content="2020 Property Rates in Ahmedabad - Search for residential property price &amp; real estate trends &amp; Compare area wise property rates across Ahmedabad. Check Property Index Ahmedabad on Makaan.com." name="description"/>
#   <meta content="Property rates in Ahmedabad, Property trends in Ahmedabad, Ahmedabad property rates, Ahmedabad property rates area wise, Ahmedabad property price, real estate trends in Ahmedabad, Ahmedabad property rates sector wise" name="keywords"/>
#   <meta content="#fff" id="themeColor" name="theme-color"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="55ce01b3ca93c05fd5a41439a23dd0d9" name="p:domain_verify"/>
#   <meta content="155462194517712" name="fb:pages"/>
# ...

# %%
# Out:
# [<span itemprop="name">home</span>,
#  <span itemprop="name">Property Rates &amp; Price Trends in India</span>,
#  <span itemprop="name">Bopal</span>,
#  <span itemprop="name">Shela</span>,
#  <span itemprop="name">Gota</span>,
#  <span itemprop="name">Chandkheda</span>,
#  <span itemprop="name">Thaltej</span>,
#  <span itemprop="name">Bodakdev</span>,
#  <span itemprop="name">Prahlad Nagar</span>,
#  <span itemprop="name">South Bopal</span>,
#  <span itemprop="name">Jodhpur</span>,
#  <span itemprop="name">Satellite</span>,
#  <span itemprop="name">Shilaj</span>,
#  <span itemprop="name">Motera</span>,
#  <span itemprop="name">Vejalpur</span>,
#  <span itemprop="name">Ambli</span>,
#  <span itemprop="name">Vastrapur</span>,
#  <span itemprop="name">Makarba</span>,
#  <span itemprop="name">Near Nirma University On SG Highway</span>,
#  <span itemprop="name">Sanand</span>,
#  <span itemprop="name">Vastral</span>,
#  <span itemprop="name">Ambavadi</span>,
# ...

# %%
# Out:
# home
# Property Rates & Price Trends in India
# Bopal
# Shela
# Gota
# Chandkheda
# Thaltej
# Bodakdev
# Prahlad Nagar
# South Bopal
# Jodhpur
# Satellite
# Shilaj
# Motera
# Vejalpur
# Ambli
# Vastrapur
# Makarba
# Near Nirma University On SG Highway
# Sanand
# Vastral
# Ambavadi
# Ghatlodiya
# Ghuma
# Jodhpur Village
# Paldi
# Navrangpura
# Science City
# Nikol
# Nava Naroda
# Naranpuraa
# Memnagar
# Maninagar
# Ranip
# Near Vaishno Devi Circle On SG Highway
# Jagatpur
# Vasna
# Sola
# New Ranip
# Sanathal
# Gurukul
# Tragad
# Jivraj Park
# Narolgam
# Chanakyapuri
# Naroda
# Vatva
# Amraiwadi
# Manipur
# Ellisbridge
# Kudasan
# Gulbai Tekra
# Ghodsar
# Juhapura
# Chandlodia
# Odhav
# Shahibuag
# Isanpur
# New Maninagar
# Shahibaug
# Rancharda
# Bapunagar
# Bopal
# Shela
# Gota
# Chandkheda
# Thaltej
# Bodakdev
# Prahlad Nagar
# South Bopal
# Jodhpur
# Satellite
# Shilaj
# Motera
# Vejalpur
# Ambli
# Vastrapur
# Makarba
# Near Nirma University On SG Highway
# Sanand
# Vastral
# ...

# %%
# Out:
# Bopal
# Shela
# Gota
# Chandkheda
# Thaltej
# Bodakdev
# Prahlad Nagar
# South Bopal
# Jodhpur
# Satellite
# Shilaj
# Motera
# Vejalpur
# Ambli
# Vastrapur
# Makarba
# Near Nirma University On SG Highway
# Sanand
# Vastral
# Ambavadi
# Ghatlodiya
# Ghuma
# Jodhpur Village
# Paldi
# Navrangpura
# Science City
# Nikol
# Nava Naroda
# Naranpuraa
# Memnagar
# Maninagar
# Ranip
# Near Vaishno Devi Circle On SG Highway
# Jagatpur
# Vasna
# Sola
# New Ranip
# Sanathal
# Gurukul
# Tragad
# Jivraj Park
# Narolgam
# Chanakyapuri
# Naroda
# Vatva
# Amraiwadi
# Manipur
# Ellisbridge
# Kudasan
# Gulbai Tekra
# Ghodsar
# Juhapura
# Chandlodia
# Odhav
# Shahibuag
# Isanpur
# New Maninagar
# Shahibaug
# Rancharda
# Bapunagar

# %%
# Out:
# 9,964.39 / sqft
#
# 12,152.33 / sqft
#
# 8,507.45 / sqft
#
# 9,20.77 / sqft
#
# 13,762.86 / sqft
#
# 14,350.21 / sqft
#
# 11,30.71 / sqft
#
# 7,960.29 / sqft
#
# 8,60.01 / sqft
#
# 34,953.46 / sqft
#
# 9,749.97 / sqft
#
# 6,500.98 / sqft
#
# 7,876.75 / sqft
#
# 13,991.88 / sqft
#
# 9,337.6 / sqft
#
# 7,328.18 / sqft
#
# 8,45.51 / sqft
#
# 6,258.38 / sqft
#
# 5,24.48 / sqft
#
# 9,721.93 / sqft
#
# 6,026 / sqft
#
# 5,986.6 / sqft
#
# 8,817.27 / sqft
#
# 7,75.72 / sqft
#
# 8,145.34 / sqft
#
# 8,541.66 / sqft
#
# 8,981.9 / sqft
#
# 6,515.15 / sqft
#
# 8,44.56 / sqft
#
# 10,635.12 / sqft
#
# 10,289.86 / sqft
#
# 6,801.49 / sqft
#
# 8,999.94 / sqft
#
# 7,225.88 / sqft
#
# 8,987.84 / sqft
#
# 8,859.01 / sqft
#
# 4,905.64 / sqft
#
# 3,897.06 / sqft
#
# 6,720.21 / sqft
#
# 8,485.29 / sqft
#
# 5,89.28 / sqft
#
# 5,861.47 / sqft
#
# 8,130.9 / sqft
#
# 4,311.12 / sqft
#
# 5,840.44 / sqft
#
# 4,220.74 / sqft
#
# 5,499.66 / sqft
#
# 8,502.26 / sqft
#
# 4,212.66 / sqft
#
# 8,160.71 / sqft
#
# ...

# %%
# Out:
# 9,964.39 / sqft
#
# 12,152.33 / sqft
#
# 8,507.45 / sqft
#
# 9,20.77 / sqft
#
# 13,762.86 / sqft
#
# 14,350.21 / sqft
#
# 11,30.71 / sqft
#
# 7,960.29 / sqft
#
# 8,60.01 / sqft
#
# 34,953.46 / sqft
#
# 9,749.97 / sqft
#
# 6,500.98 / sqft
#
# 7,876.75 / sqft
#
# 13,991.88 / sqft
#
# 9,337.6 / sqft
#
# 7,328.18 / sqft
#
# 8,45.51 / sqft
#
# 6,258.38 / sqft
#
# 5,24.48 / sqft
#
# 9,721.93 / sqft
#
# 6,026 / sqft
#
# 5,986.6 / sqft
#
# 8,817.27 / sqft
#
# 7,75.72 / sqft
#
# 8,145.34 / sqft
#
# 8,541.66 / sqft
#
# 8,981.9 / sqft
#
# 6,515.15 / sqft
#
# 8,44.56 / sqft
#
# 10,635.12 / sqft
#
# 10,289.86 / sqft
#
# 6,801.49 / sqft
#
# 8,999.94 / sqft
#
# 7,225.88 / sqft
#
# 8,987.84 / sqft
#
# 8,859.01 / sqft
#
# 4,905.64 / sqft
#
# 3,897.06 / sqft
#
# 6,720.21 / sqft
#
# 8,485.29 / sqft
#
# 5,89.28 / sqft
#
# 5,861.47 / sqft
#
# 8,130.9 / sqft
#
# 4,311.12 / sqft
#
# 5,840.44 / sqft
#
# 4,220.74 / sqft
#
# 5,499.66 / sqft
#
# 8,502.26 / sqft
#
# 4,212.66 / sqft
#
# 8,160.71 / sqft
#
# ...

# %%
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <title>
#    Property Rates in Ahmedabad - 2020 - Real Estate Property Price &amp; Trends in Ahmedabad
#   </title>
#   <meta content="2020 Property Rates in Ahmedabad - Search for residential property price &amp; real estate trends &amp; Compare area wise property rates across Ahmedabad. Check Property Index Ahmedabad on Makaan.com." name="description"/>
#   <meta content="Property rates in Ahmedabad, Property trends in Ahmedabad, Ahmedabad property rates, Ahmedabad property rates area wise, Ahmedabad property price, real estate trends in Ahmedabad, Ahmedabad property rates sector wise" name="keywords"/>
#   <meta content="#fff" id="themeColor" name="theme-color"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="55ce01b3ca93c05fd5a41439a23dd0d9" name="p:domain_verify"/>
#   <meta content="155462194517712" name="fb:pages"/>
# ...

# %%
# Out:
# 9,964.39 / sqft
#
# 12,152.33 / sqft
#
# 8,507.45 / sqft
#
# 9,20.77 / sqft
#
# 13,762.86 / sqft
#
# 14,350.21 / sqft
#
# 11,30.71 / sqft
#
# 7,960.29 / sqft
#
# 8,60.01 / sqft
#
# 34,953.46 / sqft
#
# 9,749.97 / sqft
#
# 6,500.98 / sqft
#
# 7,876.75 / sqft
#
# 13,991.88 / sqft
#
# 9,337.6 / sqft
#
# 7,328.18 / sqft
#
# 8,45.51 / sqft
#
# 6,258.38 / sqft
#
# 5,24.48 / sqft
#
# 9,721.93 / sqft
#
# 6,026 / sqft
#
# 5,986.6 / sqft
#
# 8,817.27 / sqft
#
# 7,75.72 / sqft
#
# 8,145.34 / sqft
#
# 8,541.66 / sqft
#
# 8,981.9 / sqft
#
# 6,515.15 / sqft
#
# 8,44.56 / sqft
#
# 10,635.12 / sqft
#
# 10,289.86 / sqft
#
# 6,801.49 / sqft
#
# 8,999.94 / sqft
#
# 7,225.88 / sqft
#
# 8,987.84 / sqft
#
# 8,859.01 / sqft
#
# 4,905.64 / sqft
#
# 3,897.06 / sqft
#
# 6,720.21 / sqft
#
# 8,485.29 / sqft
#
# 5,89.28 / sqft
#
# 5,861.47 / sqft
#
# 8,130.9 / sqft
#
# 4,311.12 / sqft
#
# 5,840.44 / sqft
#
# 4,220.74 / sqft
#
# 5,499.66 / sqft
#
# 8,502.26 / sqft
#
# 4,212.66 / sqft
#
# 8,160.71 / sqft
#
# ...
